# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("konsumen.csv")
print(data)
# Out:
#     Gaji  Pengeluaran
# 0   2500         1750
# 1   3800         4200
# 2   3900         3800
# 3   4350         5500
# 4   4400         3200
# 5   5500         5450
# 6   5600         5950
# 7   5750         4100
# 8   6850         6050
# 9   6900         8500
# 10  7250         9500
# 11  7350         6050
# 12  7500         8500
# 13  7800         9500
# 14  8200         8300
# 15  8500         6500
# 16  8550         8400
# 17  8750         6000
# 18  9100        10500
# 19  9100         8500

# %%
x = np.asarray(data)
print(x)
# Out:
# [[ 2500  1750]
#  [ 3800  4200]
#  [ 3900  3800]
#  [ 4350  5500]
#  [ 4400  3200]
#  [ 5500  5450]
#  [ 5600  5950]
#  [ 5750  4100]
#  [ 6850  6050]
#  [ 6900  8500]
#  [ 7250  9500]
#  [ 7350  6050]
#  [ 7500  8500]
#  [ 7800  9500]
#  [ 8200  8300]
#  [ 8500  6500]
#  [ 8550  8400]
#  [ 8750  6000]
#  [ 9100 10500]
#  [ 9100  8500]]

# %%
z = linkage(x)

# %%
print(z)
# Out:
# [[1.40000000e+01 1.60000000e+01 3.64005494e+02 2.00000000e+00]
#  [1.00000000e+00 2.00000000e+00 4.12310563e+02 2.00000000e+00]
#  [8.00000000e+00 1.10000000e+01 5.00000000e+02 2.00000000e+00]
#  [5.00000000e+00 6.00000000e+00 5.09901951e+02 2.00000000e+00]
#  [1.00000000e+01 1.30000000e+01 5.50000000e+02 2.00000000e+00]
#  [1.50000000e+01 1.70000000e+01 5.59016994e+02 2.00000000e+00]
#  [1.90000000e+01 2.00000000e+01 5.59016994e+02 3.00000000e+00]
#  [9.00000000e+00 1.20000000e+01 6.00000000e+02 2.00000000e+00]
#  [2.60000000e+01 2.70000000e+01 7.28010989e+02 5.00000000e+00]
#  [4.00000000e+00 2.10000000e+01 7.81024968e+02 3.00000000e+00]
#  [2.40000000e+01 2.80000000e+01 1.03077641e+03 7.00000000e+00]
#  [3.00000000e+00 2.30000000e+01 1.15108644e+03 3.00000000e+00]
#  [2.20000000e+01 2.50000000e+01 1.23490890e+03 4.00000000e+00]
#  [3.10000000e+01 3.20000000e+01 1.25399362e+03 7.00000000e+00]
#  [7.00000000e+00 3.30000000e+01 1.37295302e+03 8.00000000e+00]
#  [2.90000000e+01 3.40000000e+01 1.41155942e+03 1.10000000e+01]
#  [1.80000000e+01 3.00000000e+01 1.64012195e+03 8.00000000e+00]
#  [3.50000000e+01 3.60000000e+01 1.82482876e+03 1.90000000e+01]
#  [0.00000000e+00 3.70000000e+01 2.39008368e+03 2.00000000e+01]]

# %%
plt.figure(figsize=(25, 10))
plt.title('Dendogram Hierarchical Klastering')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(z)
plt.show()
