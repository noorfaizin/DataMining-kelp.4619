# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("konsumen.csv")
print(data)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 493            4      125             70             18      122  28.9
# 494            3       80              0              0        0   0.0
# 495            6      166             74              0        0  26.6
# 496            5      110             68              0        0  26.0
# 497            2       81             72             15       76  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 493                     1.144   45        1
# 494                     0.174   22        0
# 495                     0.304   66        0
# 496                     0.292   30        0
# 497                     0.547   25        0
#
# [498 rows x 9 columns]

# %%
x = np.asarray(data)
print(x)
# Out:
# [[  6.    148.     72.    ...   0.627  50.      1.   ]
#  [  1.     85.     66.    ...   0.351  31.      0.   ]
#  [  8.    183.     64.    ...   0.672  32.      1.   ]
#  ...
#  [  6.    166.     74.    ...   0.304  66.      0.   ]
#  [  5.    110.     68.    ...   0.292  30.      0.   ]
#  [  2.     81.     72.    ...   0.547  25.      0.   ]]

# %%
z = linkage(x)

# %%
print(z)
# Out:
# [[ 60.         494.           4.2446319    2.        ]
#  [ 41.         179.           4.39062638   2.        ]
#  [278.         299.           4.43837988   2.        ]
#  ...
#  [228.         247.          76.70057108   2.        ]
#  [991.         992.         105.42810643 497.        ]
#  [ 13.         993.         108.00596632 498.        ]]

# %%
plt.figure(figsize=(25, 10))
plt.title('Dendogram Hierarchical Klastering')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(z)
plt.show()
